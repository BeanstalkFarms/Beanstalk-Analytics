# %%
import os 
import sys 
import json 
from pathlib import Path 
from functools import cache
from itertools import product

cur_path = os.path.abspath(".")
if cur_path not in sys.path: 
    sys.path.append(cur_path)

import numpy as np 
import pandas as pd 
import altair as alt 
from altair import datum
from subgrounds.subgrounds import Subgrounds, Subgraph
from subgrounds.pagination import ShallowStrategy

from utils.utils import ddf, remove_prefix, load_subgraph, remove_keys, output_chart
# Out:
# https://graph.node.bean.money/subgraphs/name/beanstalk-testing
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/ALEX/Documents/code/beanstalk-data-playground/serverless/notebooks/Silo.ipynb Cell 1 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/Users/ALEX/Documents/code/beanstalk-data-playground/serverless/notebooks/Silo.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> from subgrounds.subgrounds import Subgrounds, Subgraph
#      <a href='vscode-notebook-cell:/Users/ALEX/Documents/code/beanstalk-data-playground/serverless/notebooks/Silo.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> from subgrounds.pagination import ShallowStrategy
# ---> <a href='vscode-notebook-cell:/Users/ALEX/Documents/code/beanstalk-data-playground/serverless/notebooks/Silo.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> from utils.utils import ddf, remove_prefix, load_subgraph, remove_keys, output
#
# ImportError: cannot import name 'output' from 'utils.utils' (/Users/ALEX/Documents/code/beanstalk-data-playground/serverless/notebooks/utils/utils.py)

# %%
sg, bs = load_subgraph()

# %% [markdown]
# ## Siloed Asset Breakdown

# %%
from collections import OrderedDict

# See UI logic in this directory for reference 
# https://github.com/BeanstalkFarms/Beanstalk-UI/tree/master/src/components/Analytics/Silo
beanstalk_addr = '0xC1E088fC1323b20BCBee9bd1B9fC9546db5624C5'
token_addrs = OrderedDict(dict(
    bean='0xBEA0000029AD1c77D3d5D23Ba2D8893dB9d1Efab'.lower(), 
    bean_3crv='0xc9C32cd16Bf7eFB85Ff14e0c8603cc90F6F2eE49'.lower(), 
    ur_bean='0x1BEA0050E63e05FBb5D8BA2f10cf5800B6224449'.lower(), 
    ur_bean_3crv='0x1BEA3CcD22F4EBd3d37d731BA31Eeca95713716D'.lower(), 
))
asset_ids = [f"{beanstalk_addr.lower()}-{token_addr.lower()}" for token_addr in token_addrs.values()]
queries = [
    bs.Query.siloAssetHourlySnapshots(
        first=10000, orderBy="season", orderDirection="asc",
        where={"season_gte": 6074, "siloAsset": aid}
    )
    for aid in asset_ids 
]
df_snaps_raw = pd.concat([
    sg.query_df(
        [
            q.id, 
            q.season, 
            q.timestamp, 
            q.totalDepositedAmount, 
            q.totalDepositedBDV, 
        ],
        pagination_strategy=ShallowStrategy
    )
    for q in queries
])

# %%
from collections import defaultdict

df_dep = df_snaps_raw.copy()
df_dep = remove_prefix(df_dep, 'siloAssetHourlySnapshots_').sort_values('timestamp').reset_index(drop=True)
df_dep['token'] = df_dep['id'].apply(lambda v: v.split('-')[1])
# df_dep = df_dep.groupby(['season', 'token']).last().reset_index()
# seasons = sorted(df_dep.season.unique())
# tokens = df_dep.token.unique()
# records = []
token_addr_inv = {v: k for k, v in token_addrs.items()}
# token_mult = OrderedDict(dict(
#     bean=1e-6, 
#     bean_3crv=1e-18, 
#     ur_bean=1e-6, 
#     ur_bean_3crv=1e-12, 
# ))
# last_value = defaultdict(float)
# for s, t in product(seasons, tokens):
#     metrics = {}
#     for m in ['totalDepositedAmount', 'totalDepositedBDV']: 
#         v = df_dep.loc[(df_dep.season == s) & (df_dep.token == t)][m]
#         if len(v): 
#             v = v.values[0]
#         else: 
#             v = last_value.get((t,m), 0)
#         v = v * token_mult[token_addr_inv[t]]
#         last_value[(t,m)] = v
#         metrics[m] = v
#     records.append({
#         "season": s, 
#         "token": t, 
#         **metrics 
#     })
# df_dep = pd.DataFrame(records)

df_dep['token_name'] = df_dep.token.apply(lambda v: token_addr_inv[v])

df_dep = df_dep.loc[df_dep.token_name == 'bean']
ddf(df_dep.tail(10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>season</th>
#       <th>timestamp</th>
#       <th>totalDepositedAmount</th>
#       <th>totalDepositedBDV</th>
#       <th>token</th>
#       <th>token_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1796</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6745</td>
#       <td>6745</td>
#       <td>1662217200</td>
#       <td>1776976138644</td>
#       <td>1776976463873</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1800</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6747</td>
#       <td>6747</td>
#       <td>1662220800</td>
#       <td>1825284722688</td>
#       <td>1825285047917</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1801</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6746</td>
#       <td>6746</td>
#       <td>1662220800</td>
#       <td>1727083095124</td>
#       <td>1727083420353</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1807</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6748</td>
#       <td>6748</td>
#       <td>1662228000</td>
#       <td>1825284722688</td>
#       <td>1825285047917</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1809</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6750</td>
#       <td>6750</td>
#       <td>1662231600</td>
#       <td>1824470352778</td>
#       <td>1824470678007</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1810</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6749</td>
#       <td>6749</td>
#       <td>1662231600</td>
#       <td>1824377224564</td>
#       <td>1824377549793</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1811</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6751</td>
#       <td>6751</td>
#       <td>1662238800</td>
#       <td>1823976416611</td>
#       <td>1823976735458</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1814</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6752</td>
#       <td>6752</td>
#       <td>1662242400</td>
#       <td>1824052086129</td>
#       <td>1824052404976</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1817</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6753</td>
#       <td>6753</td>
#       <td>1662246000</td>
#       <td>1823630711609</td>
#       <td>1823631030456</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#     <tr>
#       <th>1819</th>
#       <td>0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab-6754</td>
#       <td>6754</td>
#       <td>1662249600</td>
#       <td>1823740916079</td>
#       <td>1823851439396</td>
#       <td>0xbea0000029ad1c77d3d5d23ba2d8893db9d1efab</td>
#       <td>bean</td>
#     </tr>
#   </tbody>
# </table>
# <p>10 rows × 7 columns</p>

# %%
df_dep = df_dep.loc[df_dep.token_name == 'bean']
alt.Chart(df_dep).mark_line().encode(
    x=alt.X("season:O"), 
    y=alt.Y("totalDepositedAmount:Q"), 
    color=alt.Color("token_name:N"), 
    tooltip=alt.Tooltip("totalDepositedAmount:Q")
).properties(width=700)
# Out:
# alt.Chart(...)

# %%
# query SeasonalDepositedUnripeBeans {
#   siloAssetDailySnapshots(
#     where: {
#       siloAsset: "0xc1e088fc1323b20bcbee9bd1b9fc9546db5624c5-0x1bea0050e63e05fbb5d8ba2f10cf5800b6224449"
#     }
#     orderBy: season
#     orderDirection: desc
#     first: 10 
#   ) {
#     season
#     siloAsset {
#       totalDepositedAmount
#     	totalDepositedBDV
#     }
#   }
# }
