# %%
import altair as alt 
import pandas as pd 
from utils_notebook.vega import output_chart

data = pd.DataFrame(
    [{"timestamp": 1, "data": 2}, {"timestamp": 2, "data": 2}]
)
c = alt.Chart(data).mark_line().encode(
    x="timestamp:O", y="data:Q"
)
output_chart(c)
